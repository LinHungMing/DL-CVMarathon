# %% [markdown]
# # 作業
#
# 思考一下我們前面有提到圖片是矩陣，但維度可能會不一樣
# 例如灰階圖只有兩個維度，RGB 彩圖則有 3 個維度
#
# 假如今天我們把 RGB 3 個維度拆開來看會有甚麼不同的效果呢？

# %%
import cv2
import numpy as np

# %%
img_color = cv2.imread('data/lena.png',cv2.IMREAD_COLOR)
img_gray = cv2.imread('data/lena.png', cv2.IMREAD_GRAYSCALE)

while True:
    cv2.imshow('COLOR',img_color)
    cv2.imshow('GRAY',img_gray)
    
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1f9b139d5030> in <module>
#       2 img_gray = cv2.imread('data/lena.png', cv2.IMREAD_GRAYSCALE)
#       3
# ----> 4 while true:
#       5     cv2.imshow('COLOR',img_color)
#       6     cv2.imshow('GRAY',img_gray)
#
# NameError: name 'true' is not defined
